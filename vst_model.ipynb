# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"C:\Users\Suman\Desktop\GIET STUDENT'S  MARK PRED\VSTPRED.csv")

# %%
data
# Out:
#      VST1 SEM1  VST2 SEM1  VST1 SEM2  VST2 SEM2  VST1 SEM3  VST2 SEM3  \
# 0           40         29         89         47        114         79
# 1          199         98         34        109         92         46
# 2           47         70        106         75         27        113
# 3          113         83         71         26         85         71
# 4          106         47        109         65         43         74
# ..         ...        ...        ...        ...        ...        ...
# 375         61        120        120         78         49         96
# 376         84         29         70        108         93         95
# 377         69         34         84         57         78         89
# 378         80         51         40         32         93        115
# 379        105         83         67         42         65         87
#
#      VST1 SEM4  VST2 SEM4  VST1 SEM5
# 0           28         96         65
# 1           35         52         83
# ...

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#         VST1 SEM1   VST2 SEM1   VST1 SEM2   VST2 SEM2   VST1 SEM3   VST2 SEM3  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean    69.655263   68.215789   69.010526   68.889474   70.789474   70.360526
# std     29.950524   29.602213   28.952147   30.560695   29.470130   28.886531
# min     20.000000   20.000000   20.000000   20.000000   20.000000   20.000000
# 25%     45.000000   41.000000   43.750000   42.000000   46.000000   45.750000
# 50%     70.000000   68.500000   66.000000   70.000000   69.000000   69.000000
# 75%     94.000000   94.000000   94.000000   95.250000   96.000000   95.000000
# max    199.000000  120.000000  120.000000  120.000000  120.000000  120.000000
#
#         VST1 SEM4   VST2 SEM4   VST1 SEM5
# count  380.000000  380.000000  380.000000
# mean    69.355263   70.642105   69.684211
# std     29.849183   29.520679    9.908034
# min     20.000000   20.000000   42.000000
# 25%     44.000000   44.000000   63.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VST1 SEM1  380 non-null    int64
#  1   VST2 SEM1  380 non-null    int64
#  2   VST1 SEM2  380 non-null    int64
#  3   VST2 SEM2  380 non-null    int64
#  4   VST1 SEM3  380 non-null    int64
#  5   VST2 SEM3  380 non-null    int64
#  6   VST1 SEM4  380 non-null    int64
#  7   VST2 SEM4  380 non-null    int64
#  8   VST1 SEM5  380 non-null    int64
# dtypes: int64(9)
# memory usage: 26.8 KB

# %%
sns.pairplot(data)
plt.show()

# %%
data1=data.corr()

# %%
sns.heatmap(data1)
# Out:
# <AxesSubplot:>

# %%
data.sum()
# Out:
# VST1 SEM1    26469
# VST2 SEM1    25922
# VST1 SEM2    26224
# VST2 SEM2    26178
# VST1 SEM3    26900
# VST2 SEM3    26737
# VST1 SEM4    26355
# VST2 SEM4    26844
# VST1 SEM5    26480
# dtype: int64

# %%
data.mean()
# Out:
# VST1 SEM1    69.655263
# VST2 SEM1    68.215789
# VST1 SEM2    69.010526
# VST2 SEM2    68.889474
# VST1 SEM3    70.789474
# VST2 SEM3    70.360526
# VST1 SEM4    69.355263
# VST2 SEM4    70.642105
# VST1 SEM5    69.684211
# dtype: float64

# %%
X=data.drop("VST1 SEM5", axis=1)

# %%
y=data['VST1 SEM5']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=3)

# %%
print("Shape of X_train=", X_train.shape)
print("Shape of X_test", X_test.shape)
print("shape of y_train=",y_train.shape)
print("Shape of y_test", y_test.shape)
# Out:
# Shape of X_train= (266, 8)
# Shape of X_test (114, 8)
# shape of y_train= (266,)
# Shape of y_test (114,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train
      )
# Out:
# LinearRegression()

# %%
lr.predict(X_test)
# Out:
# array([64.28440799, 60.93824072, 55.30325535, 73.54792627, 61.66932364,
#        66.06453016, 71.34866336, 68.81799361, 59.70107842, 68.2065897 ,
#        76.26518389, 66.03863254, 59.54231659, 61.03269738, 62.19451367,
#        58.69665514, 81.94598464, 79.06219288, 77.3250992 , 49.42785656,
#        66.27518727, 56.55086102, 75.80618912, 72.19252271, 53.6509212 ,
#        60.5737221 , 72.56015778, 73.99443611, 67.15228625, 76.16092367,
#        72.78491831, 77.42767708, 68.02092504, 71.55736854, 87.69158958,
#        73.82184298, 57.22083557, 60.83513561, 47.91645388, 51.29630983,
#        69.13617859, 75.29737898, 78.31923931, 75.621104  , 81.78084388,
#        50.79011417, 64.56790648, 81.56682744, 63.92635373, 82.03096363,
#        70.66783081, 68.92319312, 61.66220513, 77.74812357, 75.76641086,
#        75.18249463, 86.66497975, 54.41802367, 68.81679945, 63.91837262,
#        73.28367371, 73.03240626, 67.94375256, 68.82133931, 68.40487625,
# ...

# %%
lr.score(X_test, y_test)*100
# Out:
# 99.92094939565739

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
l=Lasso()

# %%
l.fit(X_train, y_train)
# Out:
# Lasso()

# %%
l.fit(X_train, y_train)
# Out:
# Lasso()

# %%
l.score(X_train, y_train)
# Out:
# 0.999010448381773

# %%
r=Ridge()

# %%
r.fit(X_train, y_train)
# Out:
# Ridge()

# %%
r.score(X_train, y_train)
# Out:
# 0.9991134818781257

# %%
from sklearn.svm import SVR

# %%
svr_rbf = SVR(kernel='rbf')
svr_rbf.fit(X_train, y_train)
svr_rbf.score(X_test, y_test)
# Out:
# 0.8765996511345234

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
regressor = DecisionTreeRegressor(criterion='mse')
regressor.fit(X_train, y_train)
# Out:
# C:\Users\Suman\anaconda3\lib\site-packages\sklearn\tree\_classes.py:359: FutureWarning: Criterion 'mse' was deprecated in v1.0 and will be removed in version 1.2. Use `criterion='squared_error'` which is equivalent.
#   warnings.warn(
# DecisionTreeRegressor(criterion='mse')

# %%
regressor.score(X_test, y_test)
# Out:
# 0.18622702912023692

# %%
plt.figure(figsize=(16,9))
bins=[20,30,40,50,60,70,80,90,100,110,120]
plt.hist(data,bins)
plt.show()

# %%
cbar_kws={'orientation':'horizontal', 'shrink':1, 'extend':'min','extendfrac':0.1, 'ticks':np.arange(0,22), 'drawedges':True }
annot_kws={'fontsize':10, 'fontstyle':'italic', 'color':'k', 'alpha':0.8,'rotation':'vertical','backgroundcolor':'w'}
sns.heatmap(data1, vmin=0, vmax=21,cmap='coolwarm',annot=True, annot_kws=annot_kws,cbar_kws=cbar_kws)
plt.show()

# %%
import pickle

# %%
filename = 'vst_model.sav'
pickle.dump(lr, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open('vst_model.sav', 'rb'))
